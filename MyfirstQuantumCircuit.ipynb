# %%
# Import Qiskit
from qiskit import QuantumCircuit

# Create a quantum circuit with 1 qubit
qc = QuantumCircuit(1, 1)

# Add a Hadamard gate (creates superposition!)
qc.h(0)

# Measure the qubit
qc.measure(0, 0)

# Draw the circuit
qc.draw('mpl')

# %%
# Import the simulator
from qiskit import transpile
from qiskit_aer import AerSimulator

# Create a simulator
simulator = AerSimulator()

# Compile and run the circuit
compiled_circuit = transpile(qc, simulator)
job = simulator.run(compiled_circuit, shots=1000)

# Get results
result = job.result()
counts = result.get_counts()

# Display results
print("Measurement results:", counts)
# Out:
# Measurement results: {'0': 486, '1': 514}

# %%
# Import visualization
from qiskit.visualization import plot_histogram

# Plot the results
plot_histogram(counts)

# %%
# Step 1: Import the quantum circuit tool
from qiskit import QuantumCircuit
# Step 2: Create a quantum circuit
# 1 qubit (quantum bit) and 1 classical bit (for measurement result)
qc = QuantumCircuit(1, 1)

print("Circuit created successfully!")
print("Qubits:", qc.num_qubits)
print("Classical bits:", qc.num_clbits)
# Out:
# Circuit created successfully!
# Qubits: 1
# Classical bits: 1

# %%
print(qc)
# Out:
#
#   q:
#
# c: 1/
